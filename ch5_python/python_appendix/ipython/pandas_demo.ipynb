# %%
import numpy as np
import pandas as pd

# %%
df_class = pd.DataFrame({"first": ["Raimi", 'Eric', 'Ivan','Jordan','Maccoy','Chris'], 
                         "last": ["Peng", 'Schafer', 'Zeng','Zeng','Lee','Jin']})
df_class
# Out:
#     first     last
# 0   Raimi     Peng
# 1    Eric  Schafer
# 2    Ivan     Zeng
# 3  Jordan     Zeng
# 4  Maccoy      Lee
# 5   Chris      Jin

# %%
df_class.shape
# Out:
# (6, 2)

# %%
df_class.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df_class.columns
# Out:
# Index(['first', 'last'], dtype='object')

# %%
df_class['email'] = df_class['first']+df_class['last']+'@email.com'
df_class
# Out:
#     first     last                  email
# 0   Raimi     Peng    RaimiPeng@email.com
# 1    Eric  Schafer  EricSchafer@email.com
# 2    Ivan     Zeng     IvanZeng@email.com
# 3  Jordan     Zeng   JordanZeng@email.com
# 4  Maccoy      Lee    MaccoyLee@email.com
# 5   Chris      Jin     ChrisJin@email.com

# %%
df_class.drop('email',axis=1)
# Out:
#     first     last
# 0   Raimi     Peng
# 1    Eric  Schafer
# 2    Ivan     Zeng
# 3  Jordan     Zeng
# 4  Maccoy      Lee
# 5   Chris      Jin

# %%
df_class
# Out:
#     first     last                  email
# 0   Raimi     Peng    RaimiPeng@email.com
# 1    Eric  Schafer  EricSchafer@email.com
# 2    Ivan     Zeng     IvanZeng@email.com
# 3  Jordan     Zeng   JordanZeng@email.com
# 4  Maccoy      Lee    MaccoyLee@email.com
# 5   Chris      Jin     ChrisJin@email.com

# %%
df_class.drop(4,inplace=True)
df_class
# Out:
#     first     last                  email
# 0   Raimi     Peng    RaimiPeng@email.com
# 1    Eric  Schafer  EricSchafer@email.com
# 2    Ivan     Zeng     IvanZeng@email.com
# 3  Jordan     Zeng   JordanZeng@email.com
# 5   Chris      Jin     ChrisJin@email.com

# %%
df_class.set_index("email")
# Out:
#                         first     last
# email
# RaimiPeng@email.com     Raimi     Peng
# EricSchafer@email.com    Eric  Schafer
# IvanZeng@email.com       Ivan     Zeng
# JordanZeng@email.com   Jordan     Zeng
# ChrisJin@email.com      Chris      Jin

# %%
df_class
# Out:
#     first     last                  email
# 0   Raimi     Peng    RaimiPeng@email.com
# 1    Eric  Schafer  EricSchafer@email.com
# 2    Ivan     Zeng     IvanZeng@email.com
# 3  Jordan     Zeng   JordanZeng@email.com
# 5   Chris      Jin     ChrisJin@email.com

# %%
df_class.set_index("email",inplace = True)
df_class.reset_index()
# Out:
#                    email   first     last
# 0    RaimiPeng@email.com   Raimi     Peng
# 1  EricSchafer@email.com    Eric  Schafer
# 2     IvanZeng@email.com    Ivan     Zeng
# 3   JordanZeng@email.com  Jordan     Zeng
# 4     ChrisJin@email.com   Chris      Jin

# %%
df_class
# Out:
#                         first     last
# email
# RaimiPeng@email.com     Raimi     Peng
# EricSchafer@email.com    Eric  Schafer
# IvanZeng@email.com       Ivan     Zeng
# JordanZeng@email.com   Jordan     Zeng
# ChrisJin@email.com      Chris      Jin

# %%
df_class.reset_index(inplace = True)
df_class
# Out:
#                    email   first     last
# 0    RaimiPeng@email.com   Raimi     Peng
# 1  EricSchafer@email.com    Eric  Schafer
# 2     IvanZeng@email.com    Ivan     Zeng
# 3   JordanZeng@email.com  Jordan     Zeng
# 4     ChrisJin@email.com   Chris      Jin

# %%
df_class['last']
# Out:
# 0       Peng
# 1    Schafer
# 2       Zeng
# 3       Zeng
# 4        Jin
# Name: last, dtype: object

# %%
df_class['last'][1:3]
# Out:
# 1    Schafer
# 2       Zeng
# Name: last, dtype: object

# %%
df_class.set_index('first',inplace = True)
df_class
# Out:
#                         email     last
# first
# Raimi     RaimiPeng@email.com     Peng
# Eric    EricSchafer@email.com  Schafer
# Ivan       IvanZeng@email.com     Zeng
# Jordan   JordanZeng@email.com     Zeng
# Chris      ChrisJin@email.com      Jin

# %%
df_class.iloc[0:2]
# Out:
#                        email     last
# first
# Raimi    RaimiPeng@email.com     Peng
# Eric   EricSchafer@email.com  Schafer

# %%
df_class.iloc[0:2,0]
# Out:
# first
# Raimi      RaimiPeng@email.com
# Eric     EricSchafer@email.com
# Name: email, dtype: object

# %%
df_class.loc['Eric':'Jordan']
# Out:
#                         email     last
# first
# Eric    EricSchafer@email.com  Schafer
# Ivan       IvanZeng@email.com     Zeng
# Jordan   JordanZeng@email.com     Zeng

# %%
df_class.loc['Eric':'Jordan','email']
# Out:
# first
# Eric      EricSchafer@email.com
# Ivan         IvanZeng@email.com
# Jordan     JordanZeng@email.com
# Name: email, dtype: object

# %%
df_class.loc[['Eric','Jordan']]
# Out:
#                         email     last
# first
# Eric    EricSchafer@email.com  Schafer
# Jordan   JordanZeng@email.com     Zeng

# %%
df_class.loc[['Eric','Jordan'],['last','email']]
# Out:
#            last                  email
# first
# Eric    Schafer  EricSchafer@email.com
# Jordan     Zeng   JordanZeng@email.com

# %%
df_num = pd.DataFrame(np.random.randn(8, 4), columns=list('ABCD'))
df_num
# Out:
#           A         B         C         D
# 0 -0.843725 -2.075137 -1.688441 -0.180328
# 1 -0.477223  0.447065  0.788691 -1.320569
# 2 -0.773270 -0.079201  0.276951 -0.353687
# 3  0.425673 -0.715236  0.282754 -0.816120
# 4  0.294698  1.843054  1.820871 -0.575037
# 5 -1.764862  0.892863 -0.370961 -0.398521
# 6 -0.417753 -0.956988 -0.840523  1.669488
# 7 -0.950081 -0.503569 -1.102006 -2.060187

# %%
df_num['A']<0
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# Name: A, dtype: bool

# %%
df_num[df_num['A']<0]
# Out:
#           A         B         C         D
# 0 -0.843725 -2.075137 -1.688441 -0.180328
# 1 -0.477223  0.447065  0.788691 -1.320569
# 2 -0.773270 -0.079201  0.276951 -0.353687
# 5 -1.764862  0.892863 -0.370961 -0.398521
# 6 -0.417753 -0.956988 -0.840523  1.669488
# 7 -0.950081 -0.503569 -1.102006 -2.060187

# %%
filt = (df_num['A']<0) & (df_num['A']>-0.5)
filt
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# Name: A, dtype: bool

# %%
df_num[filt]
# Out:
#           A         B         C         D
# 1 -0.477223  0.447065  0.788691 -1.320569
# 6 -0.417753 -0.956988 -0.840523  1.669488

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       8 non-null      float64
#  1   B       8 non-null      float64
#  2   C       8 non-null      float64
#  3   D       8 non-null      float64
# dtypes: float64(4)
# memory usage: 384.0 bytes

# %%
df_num.head()
# Out:
#           A         B         C         D
# 0 -0.843725 -2.075137 -1.688441 -0.180328
# 1 -0.477223  0.447065  0.788691 -1.320569
# 2 -0.773270 -0.079201  0.276951 -0.353687
# 3  0.425673 -0.715236  0.282754 -0.816120
# 4  0.294698  1.843054  1.820871 -0.575037

# %%
df_num.tail(3)
# Out:
#           A         B         C         D
# 5 -1.764862  0.892863 -0.370961 -0.398521
# 6 -0.417753 -0.956988 -0.840523  1.669488
# 7 -0.950081 -0.503569 -1.102006 -2.060187

# %%
df_num.describe()
# Out:
#               A         B         C         D
# count  8.000000  8.000000  8.000000  8.000000
# mean  -0.563318 -0.143393 -0.104083 -0.504370
# std    0.702943  1.208474  1.128649  1.072614
# min   -1.764862 -2.075137 -1.688441 -2.060187
# 25%   -0.870314 -0.775674 -0.905894 -0.942232
# 50%   -0.625247 -0.291385 -0.047005 -0.486779
# 75%   -0.239640  0.558515  0.409239 -0.310348
# max    0.425673  1.843054  1.820871  1.669488

# %%
df_num.max()
# Out:
# A    0.425673
# B    1.843054
# C    1.820871
# D    1.669488
# dtype: float64

# %%
df_num.max(axis = 1)
# Out:
# 0   -0.180328
# 1    0.788691
# 2    0.276951
# 3    0.425673
# 4    1.843054
# 5    0.892863
# 6    1.669488
# 7   -0.503569
# dtype: float64

# %%
df_num2 = df_num.reindex(index=df_num.index[1:],columns=list(df_num.columns) + ['E'])
df_num2
# Out:
#           A         B         C         D   E
# 1 -0.477223  0.447065  0.788691 -1.320569 NaN
# 2 -0.773270 -0.079201  0.276951 -0.353687 NaN
# 3  0.425673 -0.715236  0.282754 -0.816120 NaN
# 4  0.294698  1.843054  1.820871 -0.575037 NaN
# 5 -1.764862  0.892863 -0.370961 -0.398521 NaN
# 6 -0.417753 -0.956988 -0.840523  1.669488 NaN
# 7 -0.950081 -0.503569 -1.102006 -2.060187 NaN

# %%
df_num2.loc[1:4,'E']=2
df_num2
# Out:
#           A         B         C         D    E
# 1 -0.477223  0.447065  0.788691 -1.320569  2.0
# 2 -0.773270 -0.079201  0.276951 -0.353687  2.0
# 3  0.425673 -0.715236  0.282754 -0.816120  2.0
# 4  0.294698  1.843054  1.820871 -0.575037  2.0
# 5 -1.764862  0.892863 -0.370961 -0.398521  NaN
# 6 -0.417753 -0.956988 -0.840523  1.669488  NaN
# 7 -0.950081 -0.503569 -1.102006 -2.060187  NaN

# %%
df_num2.loc[3:4,'B']=np.nan
df_num2
# Out:
#           A         B         C         D    E
# 1 -0.477223  0.447065  0.788691 -1.320569  2.0
# 2 -0.773270 -0.079201  0.276951 -0.353687  2.0
# 3  0.425673       NaN  0.282754 -0.816120  2.0
# 4  0.294698       NaN  1.820871 -0.575037  2.0
# 5 -1.764862  0.892863 -0.370961 -0.398521  NaN
# 6 -0.417753 -0.956988 -0.840523  1.669488  NaN
# 7 -0.950081 -0.503569 -1.102006 -2.060187  NaN

# %%
df_num2.dropna()
# Out:
#           A         B         C         D    E
# 1 -0.477223  0.447065  0.788691 -1.320569  2.0
# 2 -0.773270 -0.079201  0.276951 -0.353687  2.0

# %%
df_num2.dropna(axis = 1)
# Out:
#           A         C         D
# 1 -0.477223  0.788691 -1.320569
# 2 -0.773270  0.276951 -0.353687
# 3  0.425673  0.282754 -0.816120
# 4  0.294698  1.820871 -0.575037
# 5 -1.764862 -0.370961 -0.398521
# 6 -0.417753 -0.840523  1.669488
# 7 -0.950081 -1.102006 -2.060187

# %%
df_num2.dropna(axis = 1, how = 'all')
# Out:
#           A         B         C         D    E
# 1 -0.477223  0.447065  0.788691 -1.320569  2.0
# 2 -0.773270 -0.079201  0.276951 -0.353687  2.0
# 3  0.425673       NaN  0.282754 -0.816120  2.0
# 4  0.294698       NaN  1.820871 -0.575037  2.0
# 5 -1.764862  0.892863 -0.370961 -0.398521  NaN
# 6 -0.417753 -0.956988 -0.840523  1.669488  NaN
# 7 -0.950081 -0.503569 -1.102006 -2.060187  NaN

# %%
df_num2.fillna('not NaN')
# Out:
#           A          B         C         D        E
# 1 -0.477223   0.447065  0.788691 -1.320569        2
# 2 -0.773270 -0.0792005  0.276951 -0.353687        2
# 3  0.425673    not NaN  0.282754 -0.816120        2
# 4  0.294698    not NaN  1.820871 -0.575037        2
# 5 -1.764862   0.892863 -0.370961 -0.398521  not NaN
# 6 -0.417753  -0.956988 -0.840523  1.669488  not NaN
# 7 -0.950081  -0.503569 -1.102006 -2.060187  not NaN

# %%
df_num2.isna()
# Out:
#        A      B      C      D      E
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False   True  False  False  False
# 4  False   True  False  False  False
# 5  False  False  False  False   True
# 6  False  False  False  False   True
# 7  False  False  False  False   True

# %%
df1 = pd.DataFrame([['Ivan', 91], ['Maccoy', 80]],columns=['name', 'grade'])
df1
# Out:
#      name  grade
# 0    Ivan     91
# 1  Maccoy     80

# %%
df2 = pd.DataFrame([['Jordan', 93], ['Chris', 65]],columns=['name', 'grade'])
df2
# Out:
#      name  grade
# 0  Jordan     93
# 1   Chris     65

# %%
pd.concat([df1,df2])
# Out:
#      name  grade
# 0    Ivan     91
# 1  Maccoy     80
# 0  Jordan     93
# 1   Chris     65

# %%
pd.concat([df1,df2],ignore_index = True,axis = 1)
# Out:
#         0   1       2   3
# 0    Ivan  91  Jordan  93
# 1  Maccoy  80   Chris  65

# %%
df3 = pd.DataFrame([['Rachel', 99, 'female'], ['Joshua', 94, 'male']],columns=['name', 'grade', 'gender'])
df3
# Out:
#      name  grade  gender
# 0  Rachel     99  female
# 1  Joshua     94    male

# %%
pd.concat([df1,df3,df2],ignore_index = True,sort=False)
# Out:
#      name  grade  gender
# 0    Ivan     91     NaN
# 1  Maccoy     80     NaN
# 2  Rachel     99  female
# 3  Joshua     94    male
# 4  Jordan     93     NaN
# 5   Chris     65     NaN

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right, on=['key1', 'key2'],how='outer')
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, on=['key1', 'key2'],how='left')
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
pd.merge(left, right, on=['key1', 'key2'],how='right')
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                         'foo', 'bar', 'foo', 'foo'],
                   'B': ['one', 'one', 'two', 'three',
                         'two', 'two', 'one', 'three'],
                   'C': np.random.randn(8),
                   'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one  0.900935  0.554462
# 1  bar    one -0.382451  0.422078
# 2  foo    two -1.746437  0.171357
# 3  bar  three -0.003587  1.415849
# 4  foo    two  1.108272  0.762324
# 5  bar    two -0.208874 -1.113605
# 6  foo    one -0.846250  0.657355
# 7  foo  three -1.753233  0.768218

# %%
df.groupby('A').mean()
# Out:
#             C         D
# A
# bar -0.198304  0.241441
# foo -0.467343  0.582743

# %%
df.groupby(['A', 'B']).median()
# Out:
#                   C         D
# A   B
# bar one   -0.382451  0.422078
#     three -0.003587  1.415849
#     two   -0.208874 -1.113605
# foo one    0.027342  0.605909
#     three -1.753233  0.768218
#     two   -0.319083  0.466841

# %%
df.groupby(['B', 'A']).median()
# Out:
#                   C         D
# B     A
# one   bar -0.382451  0.422078
#       foo  0.027342  0.605909
# three bar -0.003587  1.415849
#       foo -1.753233  0.768218
# two   bar -0.208874 -1.113605
#       foo -0.319083  0.466841

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'C'}>,
#         <AxesSubplot:title={'center':'D'}>]], dtype=object)

# %%
df.to_csv('pandas_demo_df.csv')
